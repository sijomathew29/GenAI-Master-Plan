# %% [markdown]
# <a href="https://colab.research.google.com/github/sijomathew29/GenAI-Master-Plan/blob/main/Month-1/Day-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "sijo"
age = 24
height = 164.5
is_working = True

print(type(name))
print(type(age))
print(type(height))
print(type(is_working))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
name = input("Enter you name: ")
age - int(input("Enter your age: "))
height = float(input("Enter your height: "))

print("Hello", name)
print("Next year you will be", age + 1)

# %%
current_salary = float(input("Enter your current salary: "))
increase_percentage = 0.25
new_salary = current_salary * (1 + increase_percentage)
print(f"Your new salary after a 10% increase is: {new_salary:.2f}")
